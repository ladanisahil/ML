# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans 
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("bank_transactions.csv")
data
# Out:
#       TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0                T1   C5841053  10-01-1994          F   JAMSHEDPUR
# 1                T2   C2142763  04-04-1957          M      JHAJJAR
# 2                T3   C4417068  26-11-1996          F       MUMBAI
# 3                T4   C5342380  14-09-1973          F       MUMBAI
# 4                T5   C9031234  24-03-1988          F  NAVI MUMBAI
# ...             ...        ...         ...        ...          ...
# 19995        T19996   C2130963  09-08-1989          M       MUMBAI
# 19996        T19997   C1214583  02-01-1987          M      KOLKATA
# 19997        T19998   C4739783  11-02-1970          M       MUMBAI
# 19998        T19999   C4532552  21-02-1993          M        DELHI
# 19999        T20000   C6936463  27-08-1987          F     VADODARA
#
#        CustAccountBalance TransactionDate  TransactionTime  \
# 0                17819.05      02-08-2016           143207
# ...

# %%
data['TransactionDate']= pd.to_datetime(data['TransactionDate'],format='%d-%m-%y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data['TransactionDate']= pd.to_datetime(data['TransactionDate'],format='%d-%m-%y')
#
# File d:\anaconda\envs\BIA\Lib\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# File d:\anaconda\envs\BIA\Lib\site-packages\pandas\core\tools\datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
#     245 unique_dates = unique(arg)
#     246 if len(unique_dates) < len(arg):
# ...

# %%
data.describe()
# Out:
#        CustAccountBalance  TransactionTime  TransactionAmount (INR)
# count        1.997300e+04     20000.000000             20000.000000
# mean         1.210167e+05    175367.209050              1719.275140
# std          7.257977e+05     38302.047099              7191.231331
# min          0.000000e+00       400.000000                 0.000000
# 25%          5.522240e+03    152832.250000               150.000000
# 50%          1.923772e+04    184551.500000               420.000000
# 75%          6.471620e+04    203633.000000              1149.625000
# max          5.099967e+07    235951.000000            455122.000000

# %%
data.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053  10-01-1994          F   JAMSHEDPUR
# 1            T2   C2142763  04-04-1957          M      JHAJJAR
# 2            T3   C4417068  26-11-1996          F       MUMBAI
# 3            T4   C5342380  14-09-1973          F       MUMBAI
# 4            T5   C9031234  24-03-1988          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05      02-08-2016           143207
# 1             2270.69      02-08-2016           141858
# 2            17874.44      02-08-2016           142712
# 3           866503.21      02-08-2016           142714
# 4             6714.43      02-08-2016           181156
#
#    TransactionAmount (INR)
# 0                     25.0
# 1                  27999.0
# 2                    459.0
# 3                   2060.0
# 4                   1762.5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   TransactionID            20000 non-null  object
#  1   CustomerID               20000 non-null  object
#  2   CustomerDOB              19928 non-null  object
#  3   CustGender               19989 non-null  object
#  4   CustLocation             19999 non-null  object
#  5   CustAccountBalance       19973 non-null  float64
#  6   TransactionDate          20000 non-null  object
#  7   TransactionTime          20000 non-null  int64
#  8   TransactionAmount (INR)  20000 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 1.4+ MB

# %%
data.isnull().sum()
# Out:
# TransactionID               0
# CustomerID                  0
# CustomerDOB                72
# CustGender                 11
# CustLocation                1
# CustAccountBalance         27
# TransactionDate             0
# TransactionTime             0
# TransactionAmount (INR)     0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
numeric_feature = data[['CustAccountBalance','TransactionAmount (INR)']]

# %%
Scaler = StandardScaler()
Scaled_feature = Scaler.fit_transform(numeric_feature)

# %%
wcss =[]
for i in  range(1,11):
    k_means= KMeans(n_clusters = i, init='k-means++',random_state=42)
    k_means.fit(Scaled_feature)
    wcss.append(KMeans.inertia_)


plt.figure(figsize=(10,6))
plt.plot(range(1,11),wcss,Markdown='o',)
plt.xlabel('Numberof cluster(k)')
plt.ylabel('wcss')
plt.title("eblow method to find optional k")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 5
#       3     k_means= KMeans(n_clusters = i, init='k-means++',random_state=42)
#       4     k_means.fit(Scaled_feature)
# ----> 5     wcss.append(KMeans.inertia_)
#       8 plt.figure(figsize=(10,6))
#       9 plt.plot(range(1,11),wcss,Markdown='o',)
#
# AttributeError: type object 'KMeans' has no attribute 'inertia_'
